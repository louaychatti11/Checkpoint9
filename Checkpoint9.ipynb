# %%
import pandas  as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
dataset = [['Skirt', 'Sneakers', 'Scarf', 'Pants', 'Hat'],
           ['Sunglasses', 'Skirt', 'Sneakers', 'Pants', 'Hat'],
           ['Dress', 'Sandals', 'Scarf', 'Pants', 'Heels'],
           ['Dress', 'Necklace', 'Earrings', 'Scarf', 'Hat', 'Heels', 'Hat'],
           ['Earrings', 'Skirt', 'Skirt', 'Scarf', 'Shirt', 'Pants']]

df = pd.DataFrame(dataset)
df
# Out:
#             0         1         2      3      4      5     6
# 0       Skirt  Sneakers     Scarf  Pants    Hat   None  None
# 1  Sunglasses     Skirt  Sneakers  Pants    Hat   None  None
# 2       Dress   Sandals     Scarf  Pants  Heels   None  None
# 3       Dress  Necklace  Earrings  Scarf    Hat  Heels   Hat
# 4    Earrings     Skirt     Skirt  Scarf  Shirt  Pants  None

# %%
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset) 
data = pd.DataFrame(te_ary, columns=te.columns_)
data
# Out:
#    Dress  Earrings    Hat  Heels  ...  Shirt  Skirt  Sneakers  Sunglasses
# 0  False     False   True  False  ...  False   True      True       False
# 1  False     False   True  False  ...  False   True      True        True
# 2   True     False  False   True  ...  False  False     False       False
# 3   True      True   True   True  ...  False  False     False       False
# 4  False      True  False  False  ...   True   True     False       False
#
# [5 rows x 12 columns]

# %%
dataset_ = []
for i in range(len(dataset)) :
  for j in dataset[i] :
    dataset_.append(j)

plt.figure(figsize=(12,3))
for i in data.columns:
  cloth = 0
  for x in dataset_:
    if x == i:
      cloth += 1
  plt.bar(i,cloth)

# %%
itemsets_sup = apriori(data, min_support=0.5, use_colnames=True)
itemsets_sup
# Out:
#    support        itemsets
# 0      0.6           (Hat)
# 1      0.8         (Pants)
# 2      0.8         (Scarf)
# 3      0.6         (Skirt)
# 4      0.6  (Pants, Scarf)
# 5      0.6  (Pants, Skirt)

# %%
confidence_rules = association_rules(itemsets_sup, metric="confidence", min_threshold=.7)
confidence_rules
# Out:
#   antecedents consequents  antecedent support  ...    lift  leverage  conviction
# 0     (Pants)     (Scarf)                 0.8  ...  0.9375     -0.04         0.8
# 1     (Scarf)     (Pants)                 0.8  ...  0.9375     -0.04         0.8
# 2     (Pants)     (Skirt)                 0.8  ...  1.2500      0.12         1.6
# 3     (Skirt)     (Pants)                 0.6  ...  1.2500      0.12         inf
#
# [4 rows x 9 columns]

# %%
lift_rules = association_rules(itemsets_sup, metric="lift", min_threshold=1.25)
lift_rules
# Out:
#   antecedents consequents  antecedent support  ...  lift  leverage  conviction
# 0     (Skirt)     (Pants)                 0.6  ...  1.25      0.12         inf
#
# [1 rows x 9 columns]

# %%
dataset2 = pd.read_csv('Market_Basket_Optimisation.csv')
dataset2.head()
# Out:
#            shrimp    almonds     avocado  ... frozen smoothie spinach olive oil
# 0         burgers  meatballs        eggs  ...             NaN     NaN       NaN
# 1         chutney        NaN         NaN  ...             NaN     NaN       NaN
# 2          turkey    avocado         NaN  ...             NaN     NaN       NaN
# 3   mineral water       milk  energy bar  ...             NaN     NaN       NaN
# 4  low fat yogurt        NaN         NaN  ...             NaN     NaN       NaN
#
# [5 rows x 20 columns]

# %%
df_out = dataset2.apply(lambda x: list(x.dropna().values), axis=1).tolist()

te = TransactionEncoder()
te_ary2 = te.fit(df_out).transform(df_out) 
data2 = pd.DataFrame(te_ary2, columns=te.columns_)
data2.head()
# Out:
#     asparagus  almonds  antioxydant juice  ...   yams  yogurt cake  zucchini
# 0       False    False              False  ...  False        False     False
# 1       False    False              False  ...  False        False     False
# 2       False    False              False  ...  False        False     False
# 3       False    False              False  ...  False        False     False
# 4       False    False              False  ...  False        False     False
#
# [5 rows x 120 columns]

# %%
itemsets_sup2 = apriori(data2, min_support=0.05, use_colnames=True)
itemsets_sup2
# Out:
#      support                    itemsets
# 0   0.087200                   (burgers)
# 1   0.081067                      (cake)
# 2   0.060000                   (chicken)
# 3   0.163867                 (chocolate)
# 4   0.080400                   (cookies)
# 5   0.051067               (cooking oil)
# 6   0.179733                      (eggs)
# 7   0.079333                  (escalope)
# 8   0.170933              (french fries)
# 9   0.063200           (frozen smoothie)
# 10  0.095333         (frozen vegetables)
# 11  0.052400             (grated cheese)
# 12  0.132000                 (green tea)
# 13  0.098267               (ground beef)
# 14  0.076400            (low fat yogurt)
# 15  0.129600                      (milk)
# 16  0.238267             (mineral water)
# 17  0.065733                 (olive oil)
# 18  0.095067                  (pancakes)
# 19  0.071333                    (shrimp)
# 20  0.050533                      (soup)
# 21  0.174133                 (spaghetti)
# ...

# %%
confidence_rules2 = association_rules(itemsets_sup2, metric="confidence", min_threshold=.2)
confidence_rules2
# Out:
#        antecedents      consequents  ...  leverage  conviction
# 0      (chocolate)  (mineral water)  ...  0.013623    1.122506
# 1  (mineral water)      (chocolate)  ...  0.013623    1.073398
# 2  (mineral water)           (eggs)  ...  0.008109    1.043286
# 3           (eggs)  (mineral water)  ...  0.008109    1.062957
# 4  (mineral water)      (spaghetti)  ...  0.018243    1.102184
# 5      (spaghetti)  (mineral water)  ...  0.018243    1.159468
#
# [6 rows x 9 columns]

# %%
lift_rules2 = association_rules(itemsets_sup2, metric="lift", min_threshold=1)
lift_rules2
# Out:
#        antecedents      consequents  ...  leverage  conviction
# 0      (chocolate)  (mineral water)  ...  0.013623    1.122506
# 1  (mineral water)      (chocolate)  ...  0.013623    1.073398
# 2  (mineral water)           (eggs)  ...  0.008109    1.043286
# 3           (eggs)  (mineral water)  ...  0.008109    1.062957
# 4  (mineral water)      (spaghetti)  ...  0.018243    1.102184
# 5      (spaghetti)  (mineral water)  ...  0.018243    1.159468
#
# [6 rows x 9 columns]
